# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\github_work\\Conversational_AI\\Source'

# %%
import pandas as pd

df = pd.read_excel('Data/Final.xlsx',sheet_name='Sheet2')

# %%
df
# Out:
#                    Model Name  Showroom Price  Road Tax  \
# 0                         QC1           90022      1650
# 1           ACTIVA STD OBD 2B           83986     13111
# 2           ACTIVA DLX OBD 2B           94506     14513
# 3         ACTIVA SMART OBD 2B           97507     14912
# 4        ACTIVA DLX AE OBD 2B           95506     14646
# 5              DIO STD OBD 2B           79444     12507
# 6              DIO DLX OBD 2B           91299     14086
# 7      ACTIVA 125 DISC OBD 2B           99990     15244
# 8     ACTIVA 125 SMART OBD 2B          104071     22718
# 9   ACTIVA 125 DISC AE OBD 2B          100990     22103
# 10         DIO 125 STD OBD 2B           97417     14901
# 11       DIO 125 SMART OBD 2B          102812     22467
# 12           SHINE 100 OBD 2B           70562     11324
# 13        SHINE 100 DX OBD 2B           75950     12045
# 14           LIVO DRUM OBD 2B           85476     13310
# 15           LIVO DISC OBD 2B           88274     13683
# ...

# %%
df.to_csv('price.csv', index=False)
